# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cleaned_books.csv', encoding='latin1')
df = df.drop('Unnamed: 0', 1)
df.head()
# Out:
#        publisher  dagger            author primary_isbn10  price  \
# 0      Riverhead       0     Paula Hawkins     1594634025      0
# 1       Scribner       0     Anthony Doerr     1501173219      0
# 2        Vintage       0         E L James     0525431888      0
# 3   St. Martin's       0    Kristin Hannah     1466850604      0
# 4  Penguin Group       0  Kathryn Stockett     1440697663      0
#
#   primary_isbn13        date          contributor  \
# 0    9.78159E+12  2017-02-19     by Paula Hawkins
# 1     9.7815E+12  2017-05-07     by Anthony Doerr
# 2    9.78053E+12  2017-03-05       by E. L. James
# 3    9.78147E+12  2017-10-29    by Kristin Hannah
# 4    9.78144E+12  2012-04-08  by Kathryn Stockett
#
#                          title  weeks_on_list
# 0        THE GIRL ON THE TRAIN            102
# 1  ALL THE LIGHT WE CANNOT SEE             81
# 2          FIFTY SHADES DARKER             66
# 3              THE NIGHTINGALE             63
# 4                     THE HELP             58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2248 entries, 0 to 2247
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   publisher       2248 non-null   object
#  1   dagger          2248 non-null   int64
#  2   author          2248 non-null   object
#  3   primary_isbn10  2248 non-null   object
#  4   price           2248 non-null   int64
#  5   primary_isbn13  2248 non-null   object
#  6   date            2248 non-null   object
#  7   contributor     2248 non-null   object
#  8   title           2248 non-null   object
#  9   weeks_on_list   2248 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 175.8+ KB

# %%
review = pd.read_csv('review_stats.csv')
review = review.drop('Unnamed: 0', 1)
review.head()
# Out:
#          isbn  ratings_count  reviews_count  text_reviews_count  \
# 0  1594634025           4832           8435                 417
# 1  1501173219           4375          10744                 565
# 2  0525431888             71            155                   7
# 3  1466850604            631           1480                 150
# 4  1440697663           1491           1922                 330
#
#    work_ratings_count  work_reviews_count  work_text_reviews_count  \
# 0             2082071             3313269                   109917
# 1             1005586             2142471                    75056
# 2              737540             1064380                    29077
# 3              680040             1319418                    63407
# 4             2141308             3031266                    84485
#
#    average_rating
# 0            3.92
# 1            4.33
# 2            3.84
# 3            4.58
# 4            4.47

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1281 entries, 0 to 1280
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   isbn                     1281 non-null   object
#  1   ratings_count            1281 non-null   int64
#  2   reviews_count            1281 non-null   int64
#  3   text_reviews_count       1281 non-null   int64
#  4   work_ratings_count       1281 non-null   int64
#  5   work_reviews_count       1281 non-null   int64
#  6   work_text_reviews_count  1281 non-null   int64
#  7   average_rating           1281 non-null   float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 80.2+ KB

# %% [markdown]
# # Some more cleaning before merging

# %%
# Drop 'primary_isbn13' column from dataframe df
df = df.drop(columns='primary_isbn13', axis=1).copy()
df.head()
# Out:
#        publisher  dagger            author primary_isbn10  price        date  \
# 0      Riverhead       0     Paula Hawkins     1594634025      0  2017-02-19
# 1       Scribner       0     Anthony Doerr     1501173219      0  2017-05-07
# 2        Vintage       0         E L James     0525431888      0  2017-03-05
# 3   St. Martin's       0    Kristin Hannah     1466850604      0  2017-10-29
# 4  Penguin Group       0  Kathryn Stockett     1440697663      0  2012-04-08
#
#            contributor                        title  weeks_on_list
# 0     by Paula Hawkins        THE GIRL ON THE TRAIN            102
# 1     by Anthony Doerr  ALL THE LIGHT WE CANNOT SEE             81
# 2       by E. L. James          FIFTY SHADES DARKER             66
# 3    by Kristin Hannah              THE NIGHTINGALE             63
# 4  by Kathryn Stockett                     THE HELP             58

# %%
# Rename the 'primary_isbn10' column from dataframe df
df = df.rename(columns={'primary_isbn10':'isbn'})
df.head()
# Out:
#        publisher  dagger            author        isbn  price        date  \
# 0      Riverhead       0     Paula Hawkins  1594634025      0  2017-02-19
# 1       Scribner       0     Anthony Doerr  1501173219      0  2017-05-07
# 2        Vintage       0         E L James  0525431888      0  2017-03-05
# 3   St. Martin's       0    Kristin Hannah  1466850604      0  2017-10-29
# 4  Penguin Group       0  Kathryn Stockett  1440697663      0  2012-04-08
#
#            contributor                        title  weeks_on_list
# 0     by Paula Hawkins        THE GIRL ON THE TRAIN            102
# 1     by Anthony Doerr  ALL THE LIGHT WE CANNOT SEE             81
# 2       by E. L. James          FIFTY SHADES DARKER             66
# 3    by Kristin Hannah              THE NIGHTINGALE             63
# 4  by Kathryn Stockett                     THE HELP             58

# %% [markdown]
# # Merging two dataframes

# %% [markdown]
# Merging two dataframes df and review via INNER JOIN

# %%
data = df.merge(review, on='isbn', how='inner')
data.head()
# Out:
#        publisher  dagger            author        isbn  price        date  \
# 0      Riverhead       0     Paula Hawkins  1594634025      0  2017-02-19
# 1       Scribner       0     Anthony Doerr  1501173219      0  2017-05-07
# 2        Vintage       0         E L James  0525431888      0  2017-03-05
# 3   St. Martin's       0    Kristin Hannah  1466850604      0  2017-10-29
# 4  Penguin Group       0  Kathryn Stockett  1440697663      0  2012-04-08
#
#            contributor                        title  weeks_on_list  \
# 0     by Paula Hawkins        THE GIRL ON THE TRAIN            102
# 1     by Anthony Doerr  ALL THE LIGHT WE CANNOT SEE             81
# 2       by E. L. James          FIFTY SHADES DARKER             66
# 3    by Kristin Hannah              THE NIGHTINGALE             63
# 4  by Kathryn Stockett                     THE HELP             58
#
#    ratings_count  reviews_count  text_reviews_count  work_ratings_count  \
# 0           4832           8435                 417             2082071
# 1           4375          10744                 565             1005586
# 2             71            155                   7              737540
# 3            631           1480                 150              680040
# 4           1491           1922                 330             2141308
#
#    work_reviews_count  work_text_reviews_count  average_rating
# 0             3313269                   109917            3.92
# 1             2142471                    75056            4.33
# 2             1064380                    29077            3.84
# 3             1319418                    63407            4.58
# 4             3031266                    84485            4.47

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1287 entries, 0 to 1286
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   publisher                1287 non-null   object
#  1   dagger                   1287 non-null   int64
#  2   author                   1287 non-null   object
#  3   isbn                     1287 non-null   object
#  4   price                    1287 non-null   int64
#  5   date                     1287 non-null   object
#  6   contributor              1287 non-null   object
#  7   title                    1287 non-null   object
#  8   weeks_on_list            1287 non-null   int64
#  9   ratings_count            1287 non-null   int64
#  10  reviews_count            1287 non-null   int64
#  11  text_reviews_count       1287 non-null   int64
#  12  work_ratings_count       1287 non-null   int64
#  13  work_reviews_count       1287 non-null   int64
#  14  work_text_reviews_count  1287 non-null   int64
#  15  average_rating           1287 non-null   float64
# dtypes: float64(1), int64(9), object(6)
# memory usage: 170.9+ KB

# %% [markdown]
# ##### Comment:
# The new merged dataframe has more data points than in 'review' dataframe. Therefore, there must be some duplicates and we need to eliminate them

# %%
# Check for duplicates based on ISBNs
data['isbn'].duplicated().sum()
# Out:
# 6

# %%
# Review these duplicates
data[data.duplicated(['isbn'])]
# Out:
#                        publisher  dagger             author        isbn  \
# 708                Penguin Group       0       Junot DÃ_az  1594487367
# 712             Simon & Schuster       0   Philippa Gregory  1451626142
# 715        Kensington Publishing       0       Lisa Jackson  0758279590
# 735     HarperCollins Publishers       0  Christopher Moore  0061779741
# 738     HarperCollins Publishers       0   Adriana Trigiani  0062098063
# 1176  Knopf Doubleday Publishing       0      Stieg Larsson  0307593673
#
#       price        date           contributor  \
# 708       0  2012-09-30       by Junot DÃ_az
# 712       0  2012-09-02   by Philippa Gregory
# 715       0  2012-08-26       by Lisa Jackson
# 735       0  2012-04-22  by Christopher Moore
# 738       0  2012-04-22   by Adriana Trigiani
# 1176      0  2012-05-20      by Stieg Larsson
#
#                                            title  weeks_on_list  \
# 708                     THIS IS HOW YOU LOSE HER              1
# 712                THE KINGMAKERÂÃÂªS DAUGHTER              1
# 715                  YOU DONÂÃÂªT WANT TO KNOW              1
# 735                                SACRÃÃ¤ BLEU              1
# 738                    THE SHOEMAKERÂÃÂªS WIFE              1
# 1176  THE GIRL WHO KICKED THE HORNETÂÃÂªS NEST              0
#
#       ratings_count  reviews_count  text_reviews_count  work_ratings_count  \
# 708           81070         184021                6826               89177
# 712              36             53                   7               38213
# 715              13             24                   5                7699
# 735           24173          49976                2949               30011
# 738              74            131                  28               75077
# 1176           4544           5893                 626              640541
#
#       work_reviews_count  work_text_reviews_count  average_rating
# 708               197155                     7548            3.75
# 712                86153                     2849            3.97
# 715                18878                      908            3.79
# 735                60835                     3599            3.79
# 738               136629                     8296            3.99
# 1176              961876                    28953            4.22

# %%
# Drop these duplicates (with the same ISBNs) from the merged dataframe
data.drop_duplicates(subset ='isbn', inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1281 entries, 0 to 1286
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   publisher                1281 non-null   object
#  1   dagger                   1281 non-null   int64
#  2   author                   1281 non-null   object
#  3   isbn                     1281 non-null   object
#  4   price                    1281 non-null   int64
#  5   date                     1281 non-null   object
#  6   contributor              1281 non-null   object
#  7   title                    1281 non-null   object
#  8   weeks_on_list            1281 non-null   int64
#  9   ratings_count            1281 non-null   int64
#  10  reviews_count            1281 non-null   int64
#  11  text_reviews_count       1281 non-null   int64
#  12  work_ratings_count       1281 non-null   int64
#  13  work_reviews_count       1281 non-null   int64
#  14  work_text_reviews_count  1281 non-null   int64
#  15  average_rating           1281 non-null   float64
# dtypes: float64(1), int64(9), object(6)
# memory usage: 170.1+ KB

# %% [markdown]
# # Rename books' titles that are not in the right font

# %%
data['title'] = data['title'].str.encode('iso-8859-1')

# %%
data[712:].head()
# Out:
#                     publisher  dagger           author        isbn  price  \
# 714     Kensington Publishing       0     Lisa Jackson  0758279590      0
# 716                 Harlequin       0    Susan Mallery  1459234537      0
# 717  HarperCollins Publishers       0        J A Jance  0062132385      0
# 718          Simon & Schuster       0  James Lee Burke  1451648154      0
# 719                 Zondervan       0  Karen Kingsbury  0310333644      0
#
#            date         contributor  \
# 714  2012-08-26     by Lisa Jackson
# 716  2012-08-19    by Susan Mallery
# 717  2012-08-12      by J. A. Jance
# 718  2012-08-05  by James Lee Burke
# 719  2012-07-15  by Karen Kingsbury
#
#                                                 title  weeks_on_list  \
# 714  b'YOU DON\xc3\xa2\xc2\x80\xc2\x99T WANT TO KNOW'              1
# 716                                b'ALL SUMMER LONG'              1
# 717                                  b'JUDGMENT CALL'              1
# 718                                   b'CREOLE BELLE'              1
# 719                                    b'COMING HOME'              1
#
#      ratings_count  reviews_count  text_reviews_count  work_ratings_count  \
# 714             13             24                   5                7699
# 716             49             64                   8               10347
# 717             28             49                  11                6071
# 718              9             19                   2                6992
# 719              1              9                   0                5493
#
#      work_reviews_count  work_text_reviews_count  average_rating
# 714               18878                      908            3.79
# 716               17706                      512            4.15
# 717               10834                      520            4.05
# 718               11570                      836            4.17
# 719               11043                      546            4.39

# %% [markdown]
# # Save the cleaned merged dataframe into a new CSV file

# %%
# data.to_csv('merge_data.csv')
